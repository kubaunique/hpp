# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pandas import read_csv
from matplotlib import pyplot
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from pandas import set_option
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import numpy
import seaborn as sns
# Out:
#   File "<ipython-input-50-c58de8816f58>", line 19
#     Importing Dependencies
#               ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras_tuner.tuners import RandomSearch
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# !pip install keras-tuner --upgrade
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.6-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.14.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.11.17)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.6 kt-legacy-1.0.5

# %%
df = pd.read_csv("/content/Housing.csv")

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
plt.figure
sns.histplot(df['price'], kde=True)
plt.title('House Price Distribution')
plt.xlabel('Price')
plt.show()

# %%
sns.barplot(x=df['airconditioning'],y=df['bedrooms'],hue=df["furnishingstatus"])
# Out:
# <Axes: xlabel='airconditioning', ylabel='bedrooms'>

# %%
fig, axs = plt.subplots(2,3, figsize = (10,5))
plt1 = sns.boxplot(df['price'], ax = axs[0,0])
plt2 = sns.boxplot(df['area'], ax = axs[0,1])
plt3 = sns.boxplot(df['bedrooms'], ax = axs[0,2])
plt1 = sns.boxplot(df['bathrooms'], ax = axs[1,0])
plt2 = sns.boxplot(df['stories'], ax = axs[1,1])
plt3 = sns.boxplot(df['parking'], ax = axs[1,2])

plt.tight_layout()

# %%
sns.boxplot(x = 'furnishingstatus', y = 'price', hue = 'airconditioning', data = df)
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='price'>

# %%
sns.scatterplot(y=df['price'],x=df['area'],hue=df['furnishingstatus'])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
sns.pairplot(df)
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot = True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='airconditioning', data=df)
plt.title('Counts of Air Conditioning')
plt.xlabel('Air Conditioning')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='bedrooms', y='price', data=df)
plt.title('Price by Bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='furnishingstatus', data=df)
plt.title('Counts of Furnishing Status')
plt.xlabel('Furnishing Status')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='mainroad', y='price', data=df)
plt.title('Price by Mainroad')
plt.xlabel('Mainroad')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['area'], kde=True, color='green')
plt.title('Distribution of Area')
plt.xlabel('Area')
plt.ylabel('Count')
plt.show()

# %%
encoded_data = pd.get_dummies( df,columns=['mainroad','guestroom','basement','hotwaterheating','airconditioning','prefarea','furnishingstatus'])
encoded_data.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking',
#        'mainroad_no', 'mainroad_yes', 'guestroom_no', 'guestroom_yes',
#        'basement_no', 'basement_yes', 'hotwaterheating_no',
#        'hotwaterheating_yes', 'airconditioning_no', 'airconditioning_yes',
#        'prefarea_no', 'prefarea_yes', 'furnishingstatus_furnished',
#        'furnishingstatus_semi-furnished', 'furnishingstatus_unfurnished'],
#       dtype='object')

# %%
sns.heatmap(encoded_data.corr(), cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
encoded_data.shape
# Out:
# (545, 21)

# %%
encoded_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   price                            545 non-null    int64
#  1   area                             545 non-null    int64
#  2   bedrooms                         545 non-null    int64
#  3   bathrooms                        545 non-null    int64
#  4   stories                          545 non-null    int64
#  5   parking                          545 non-null    int64
#  6   mainroad_no                      545 non-null    uint8
#  7   mainroad_yes                     545 non-null    uint8
#  8   guestroom_no                     545 non-null    uint8
#  9   guestroom_yes                    545 non-null    uint8
#  10  basement_no                      545 non-null    uint8
#  11  basement_yes                     545 non-null    uint8
#  12  hotwaterheating_no               545 non-null    uint8
#  13  hotwaterheating_yes              545 non-null    uint8
#  14  airconditioning_no               545 non-null    uint8
#  15  airconditioning_yes              545 non-null    uint8
#  16  prefarea_no                      545 non-null    uint8
#  17  prefarea_yes                     545 non-null    uint8
#  18  furnishingstatus_furnished       545 non-null    uint8
#  19  furnishingstatus_semi-furnished  545 non-null    uint8
#  20  furnishingstatus_unfurnished     545 non-null    uint8
# dtypes: int64(6), uint8(15)
# memory usage: 33.7 KB

# %%
X = encoded_data.drop(['price'],axis=1)
Y = encoded_data['price']

# %%
sc = StandardScaler()
X_scaled = sc.fit_transform(X)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y,
test_size=0.2, random_state=100)

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(layers.Input(shape=(20,)))

    hp_units1 = hp.Int('units1', min_value=32, max_value=512, step=32)
    hp_activation1 = hp.Choice('activation1', values=['relu', 'tanh', 'sigmoid'])

    model.add(layers.Dense(units=hp_units1, activation=hp_activation1))

    hp_units2 = hp.Int('units2', min_value=32, max_value=512, step=32)
    hp_activation2 = hp.Choice('activation2', values=['relu', 'tanh', 'sigmoid'])

    model.add(layers.Dense(units=hp_units2, activation=hp_activation2))

    model.add(layers.Dense(1, activation='linear'))

    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                  loss='mean_squared_error',
                  metrics=['mean_absolute_error'])

    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=10,
    executions_per_trial=3,
    directory='my_dir',
    project_name='my_project'
)

# %%
tuner.search(X_train, Y_train, validation_data=(X_test, Y_test), epochs=10)
# Out:
# Trial 10 Complete [00h 00m 09s]
# val_loss: 18442661571242.668
#
# Best val_loss So Far: 18442661571242.668
# Total elapsed time: 00h 01m 24s

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in my_dir/my_project
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 09 summary
# Hyperparameters:
# units1: 96
# activation1: relu
# units2: 352
# activation2: relu
# learning_rate: 0.01
# Score: 18442661571242.668
#
# Trial 03 summary
# Hyperparameters:
# units1: 320
# activation1: sigmoid
# units2: 96
# activation2: relu
# learning_rate: 0.001
# Score: 25155327754240.0
#
# Trial 08 summary
# Hyperparameters:
# units1: 384
# activation1: tanh
# units2: 128
# activation2: tanh
# learning_rate: 0.01
# Score: 25157340321109.332
#
# Trial 01 summary
# Hyperparameters:
# units1: 96
# activation1: relu
# units2: 32
# activation2: relu
# learning_rate: 0.001
# Score: 25157928222720.0
#
# Trial 07 summary
# Hyperparameters:
# units1: 160
# activation1: sigmoid
# units2: 96
# activation2: sigmoid
# learning_rate: 0.01
# Score: 25157964573354.668
#
# Trial 05 summary
# Hyperparameters:
# units1: 384
# activation1: tanh
# units2: 288
# activation2: tanh
# learning_rate: 0.001
# Score: 25158270058496.0
#
# Trial 00 summary
# Hyperparameters:
# units1: 352
# activation1: sigmoid
# units2: 32
# activation2: tanh
# learning_rate: 0.01
# Score: 25158275650901.332
#
# Trial 06 summary
# Hyperparameters:
# units1: 32
# activation1: sigmoid
# units2: 352
# activation2: sigmoid
# learning_rate: 0.001
# Score: 25158351148373.332
#
# Trial 04 summary
# Hyperparameters:
# units1: 192
# activation1: relu
# units2: 256
# activation2: sigmoid
# learning_rate: 0.001
# Score: 25158431539200.0
#
# Trial 02 summary
# Hyperparameters:
# units1: 288
# activation1: sigmoid
# units2: 256
# activation2: tanh
# learning_rate: 0.0001
# Score: 25158567854080.0

# %%
# Get the best model
best_model = tuner.get_best_models(num_models=1)[0]

# Train the best model
best_model.fit(X_train, Y_train, epochs=50, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/50
# 14/14 [==============================] - 1s 15ms/step - loss: 18418904334336.0000 - mean_absolute_error: 4046165.7500 - val_loss: 15382692757504.0000 - val_mean_absolute_error: 3694938.5000
# Epoch 2/50
# 14/14 [==============================] - 0s 6ms/step - loss: 15971635953664.0000 - mean_absolute_error: 3770253.0000 - val_loss: 12866122940416.0000 - val_mean_absolute_error: 3364660.5000
# Epoch 3/50
# 14/14 [==============================] - 0s 5ms/step - loss: 13421487587328.0000 - mean_absolute_error: 3440200.5000 - val_loss: 10575808561152.0000 - val_mean_absolute_error: 3005458.5000
# Epoch 4/50
# 14/14 [==============================] - 0s 5ms/step - loss: 11103633408000.0000 - mean_absolute_error: 3094106.5000 - val_loss: 8659265388544.0000 - val_mean_absolute_error: 2671228.0000
# Epoch 5/50
# 14/14 [==============================] - 0s 6ms/step - loss: 9125608030208.0000 - mean_absolute_error: 2764444.2500 - val_loss: 7296230359040.0000 - val_mean_absolute_error: 2413122.2500
# Epoch 6/50
# 14/14 [==============================] - 0s 6ms/step - loss: 7705765347328.0000 - mean_absolute_error: 2489477.2500 - val_loss: 6357034467328.0000 - val_mean_absolute_error: 2224957.0000
# Epoch 7/50
# 14/14 [==============================] - 0s 6ms/step - loss: 6576858988544.0000 - mean_absolute_error: 2268661.2500 - val_loss: 5747292766208.0000 - val_mean_absolute_error: 2109847.2500
# Epoch 8/50
# 14/14 [==============================] - 0s 6ms/step - loss: 5801562341376.0000 - mean_absolute_error: 2113202.7500 - val_loss: 5276905242624.0000 - val_mean_absolute_error: 2001015.7500
# Epoch 9/50
# 14/14 [==============================] - 0s 6ms/step - loss: 5198710308864.0000 - mean_absolute_error: 1980937.7500 - val_loss: 4826532937728.0000 - val_mean_absolute_error: 1887527.6250
# Epoch 10/50
# 14/14 [==============================] - 0s 6ms/step - loss: 4686273839104.0000 - mean_absolute_error: 1859720.5000 - val_loss: 4404690812928.0000 - val_mean_absolute_error: 1772874.0000
# Epoch 11/50
# 14/14 [==============================] - 0s 6ms/step - loss: 4233519693824.0000 - mean_absolute_error: 1745633.7500 - val_loss: 4009045262336.0000 - val_mean_absolute_error: 1657798.0000
# Epoch 12/50
# 14/14 [==============================] - 0s 5ms/step - loss: 3803523317760.0000 - mean_absolute_error: 1632972.7500 - val_loss: 3603755171840.0000 - val_mean_absolute_error: 1551406.5000
# Epoch 13/50
# 14/14 [==============================] - 0s 6ms/step - loss: 3444413562880.0000 - mean_absolute_error: 1531545.2500 - val_loss: 3226779516928.0000 - val_mean_absolute_error: 1448699.7500
# Epoch 14/50
# 14/14 [==============================] - 0s 6ms/step - loss: 3126016081920.0000 - mean_absolute_error: 1434876.5000 - val_loss: 2952024293376.0000 - val_mean_absolute_error: 1370424.2500
# Epoch 15/50
# 14/14 [==============================] - 0s 6ms/step - loss: 2850622013440.0000 - mean_absolute_error: 1350750.6250 - val_loss: 2711514513408.0000 - val_mean_absolute_error: 1307201.6250
# Epoch 16/50
# 14/14 [==============================] - 0s 6ms/step - loss: 2622165614592.0000 - mean_absolute_error: 1281646.1250 - val_loss: 2519694311424.0000 - val_mean_absolute_error: 1261625.8750
# Epoch 17/50
# 14/14 [==============================] - 0s 6ms/step - loss: 2437042405376.0000 - mean_absolute_error: 1218132.7500 - val_loss: 2376302067712.0000 - val_mean_absolute_error: 1223718.2500
# Epoch 18/50
# 14/14 [==============================] - 0s 6ms/step - loss: 2283468226560.0000 - mean_absolute_error: 1167783.8750 - val_loss: 2233760219136.0000 - val_mean_absolute_error: 1184997.2500
# Epoch 19/50
# 14/14 [==============================] - 0s 5ms/step - loss: 2155384274944.0000 - mean_absolute_error: 1123677.6250 - val_loss: 2142824693760.0000 - val_mean_absolute_error: 1159177.1250
# Epoch 20/50
# 14/14 [==============================] - 0s 6ms/step - loss: 2053433982976.0000 - mean_absolute_error: 1092982.6250 - val_loss: 2084098408448.0000 - val_mean_absolute_error: 1143156.5000
# Epoch 21/50
# 14/14 [==============================] - 0s 6ms/step - loss: 1970900434944.0000 - mean_absolute_error: 1067995.5000 - val_loss: 2001874976768.0000 - val_mean_absolute_error: 1121685.1250
# Epoch 22/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1897620439040.0000 - mean_absolute_error: 1044910.6875 - val_loss: 1940544815104.0000 - val_mean_absolute_error: 1102556.0000
# Epoch 23/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1839204663296.0000 - mean_absolute_error: 1026367.1250 - val_loss: 1876933607424.0000 - val_mean_absolute_error: 1081426.8750
# Epoch 24/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1780920090624.0000 - mean_absolute_error: 1010862.4375 - val_loss: 1847726178304.0000 - val_mean_absolute_error: 1070406.0000
# Epoch 25/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1729624408064.0000 - mean_absolute_error: 996656.1250 - val_loss: 1797365039104.0000 - val_mean_absolute_error: 1054792.0000
# Epoch 26/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1685012480000.0000 - mean_absolute_error: 983210.6875 - val_loss: 1745588322304.0000 - val_mean_absolute_error: 1037658.3750
# Epoch 27/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1641535111168.0000 - mean_absolute_error: 970902.0625 - val_loss: 1721943326720.0000 - val_mean_absolute_error: 1028468.5625
# Epoch 28/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1603800924160.0000 - mean_absolute_error: 959758.6250 - val_loss: 1693914628096.0000 - val_mean_absolute_error: 1018531.6875
# Epoch 29/50
# 14/14 [==============================] - 0s 6ms/step - loss: 1564735307776.0000 - mean_absolute_error: 948953.3750 - val_loss: 1670928662528.0000 - val_mean_absolute_error: 1009743.6875
# Epoch 30/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1527959912448.0000 - mean_absolute_error: 935227.1250 - val_loss: 1615575121920.0000 - val_mean_absolute_error: 990826.1250
# Epoch 31/50
# 14/14 [==============================] - 0s 6ms/step - loss: 1494740238336.0000 - mean_absolute_error: 923736.5625 - val_loss: 1585841045504.0000 - val_mean_absolute_error: 980110.1875
# Epoch 32/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1468208906240.0000 - mean_absolute_error: 914268.6875 - val_loss: 1551684075520.0000 - val_mean_absolute_error: 968044.1875
# Epoch 33/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1437970857984.0000 - mean_absolute_error: 905463.6250 - val_loss: 1542655836160.0000 - val_mean_absolute_error: 964345.9375
# Epoch 34/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1409851195392.0000 - mean_absolute_error: 898214.8750 - val_loss: 1511092781056.0000 - val_mean_absolute_error: 952133.1875
# Epoch 35/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1385576529920.0000 - mean_absolute_error: 889211.2500 - val_loss: 1493728493568.0000 - val_mean_absolute_error: 944594.1250
# Epoch 36/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1359930982400.0000 - mean_absolute_error: 881041.7500 - val_loss: 1475195699200.0000 - val_mean_absolute_error: 936905.0000
# Epoch 37/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1339978416128.0000 - mean_absolute_error: 872747.7500 - val_loss: 1449285386240.0000 - val_mean_absolute_error: 927683.3750
# Epoch 38/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1320115240960.0000 - mean_absolute_error: 866262.6875 - val_loss: 1437436346368.0000 - val_mean_absolute_error: 923216.3125
# Epoch 39/50
# 14/14 [==============================] - 0s 6ms/step - loss: 1299655688192.0000 - mean_absolute_error: 858650.8125 - val_loss: 1406514626560.0000 - val_mean_absolute_error: 909937.3125
# Epoch 40/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1278738563072.0000 - mean_absolute_error: 851551.0625 - val_loss: 1404667035648.0000 - val_mean_absolute_error: 908541.6250
# Epoch 41/50
# 14/14 [==============================] - 0s 6ms/step - loss: 1258682712064.0000 - mean_absolute_error: 845817.0000 - val_loss: 1382916685824.0000 - val_mean_absolute_error: 899882.5000
# Epoch 42/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1243375468544.0000 - mean_absolute_error: 839567.8750 - val_loss: 1365948104704.0000 - val_mean_absolute_error: 891757.1875
# Epoch 43/50
# 14/14 [==============================] - 0s 6ms/step - loss: 1226949001216.0000 - mean_absolute_error: 833430.3125 - val_loss: 1343008145408.0000 - val_mean_absolute_error: 881697.0000
# Epoch 44/50
# 14/14 [==============================] - 0s 7ms/step - loss: 1209711460352.0000 - mean_absolute_error: 827435.0625 - val_loss: 1331144032256.0000 - val_mean_absolute_error: 876586.6875
# Epoch 45/50
# 14/14 [==============================] - 0s 6ms/step - loss: 1198014726144.0000 - mean_absolute_error: 823447.5000 - val_loss: 1323383783424.0000 - val_mean_absolute_error: 873979.0000
# Epoch 46/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1185516617728.0000 - mean_absolute_error: 817959.6875 - val_loss: 1297026908160.0000 - val_mean_absolute_error: 861794.1250
# Epoch 47/50
# 14/14 [==============================] - 0s 6ms/step - loss: 1170516082688.0000 - mean_absolute_error: 813187.2500 - val_loss: 1295005908992.0000 - val_mean_absolute_error: 861095.6250
# Epoch 48/50
# 14/14 [==============================] - 0s 6ms/step - loss: 1161576448000.0000 - mean_absolute_error: 810155.2500 - val_loss: 1291881545728.0000 - val_mean_absolute_error: 860832.4375
# Epoch 49/50
# 14/14 [==============================] - 0s 5ms/step - loss: 1148762849280.0000 - mean_absolute_error: 806470.1875 - val_loss: 1287567966208.0000 - val_mean_absolute_error: 859152.7500
# Epoch 50/50
# 14/14 [==============================] - 0s 6ms/step - loss: 1140864974848.0000 - mean_absolute_error: 803413.5625 - val_loss: 1278574198784.0000 - val_mean_absolute_error: 855790.3750

# %%
y_pred = best_model.predict(X_test)
y_pred = (y_pred > 0.5)
# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(Y_test, y_pred)
print(f'MAE: {mae}')

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(Y_test, y_pred)
print(f'MSE: {mse}')

# Calculate Root Mean Squared Error (RMSE)
rmse = mean_squared_error(Y_test, y_pred, squared=False)
print(f'RMSE: {rmse}')

# Calculate Root Mean Squared Logarithmic Error (RMSLE)
rmsle = mean_squared_log_error(Y_test, y_pred, squared=False)
print(f'RMSLE: {rmsle}')

# Calculate R-squared (Coefficient of Determination)
r2 = r2_score(Y_test, y_pred)
print(f'R-squared (R2): {r2}')
# Out:
# 4/4 [==============================] - 0s 3ms/step
# MAE: 4650728.357798165
# MSE: 25158755127441.367
# RMSE: 5015850.389260167
# RMSLE: 14.587722738763139
# R-squared (R2): -6.128174385493444
